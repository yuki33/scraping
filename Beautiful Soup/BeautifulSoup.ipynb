# %% [markdown]
# # スクレイピングの練習

# %% [markdown]
# ## HTMLからデータを取得し、エクセルファイルに変換（pandas.read_html() )<br>
# https://note.nkmk.me/python-pandas-web-html-table-scraping/

# %% [markdown]
# ### Yahoo!ファイナンスの時価総額ランキング

# %%
import pandas as pd

# %%
url = 'https://info.finance.yahoo.co.jp/ranking/?kd=4'
dfs = pd.read_html(url)

# %%
dfs
# Out:
# [    順位   コード      市場                    名称    取引値  発行済み株式数    時価総額（百万円）  \
#  0    1  7203    東証1部             トヨタ自動車(株)  15:00     7116   3262997492
#  1    2  9437    東証1部             (株)ＮＴＴドコモ  15:00   2839.5   3782299000
#  2    3  9432    東証1部             日本電信電話(株)  15:00     5085   2096394470
#  3    4  8306    東証1部  (株)三菱ＵＦＪフィナンシャル・グループ  15:00    630.2  13900028020
#  4    5  9984    東証1部         ソフトバンクグループ(株)  15:00     7842   1100660365
#  5    6  9433    東証1部               ＫＤＤＩ(株)  15:00     3057   2532004445
#  6    7  6861    東証1部              (株)キーエンス  15:00    63220    121603842
#  7    8  6758    東証1部                ソニー(株)  15:00     5726   1268440749
#  8    9  8686  東証1部外国                 アフラック  13:23     4805   1345761800
#  9   10  8316    東証1部    (株)三井住友フィナンシャルグループ  15:00     4295   1414443390
#  10  11  2914    東証1部                    ＪＴ  15:00     3032   2000000000
#  11  12  7267    東証1部                   ホンダ  15:00     3229   1811428430
#  12  13  7182    東証1部             (株)ゆうちょ銀行  15:00     1284   4500000000
#  13  14  6178    東証1部               日本郵政(株)  15:00     1208   4500000000
#  14  15  9983    東証1部        (株)ファーストリテイリング  15:00    50940    106073656
#  15  16  6098    東証1部      (株)リクルートホールディングス  15:00     3071   1695960030
#  16  17  7974    東証1部                任天堂(株)  15:00    36030    141669000
#  17  18  6594    東証1部               日本電産(株)  15:00    16645    298142234
#  18  19  8058    東証1部               三菱商事(株)  15:00     3081   1590076851
#  19  20  9022    東証1部             東海旅客鉄道(株)  15:00    23335    206000000
#  20  21  7751    東証1部               キヤノン(株)  15:00     3589   1333763464
#  21  22  8411    東証1部     (株)みずほフィナンシャルグループ  15:00    185.9  25392498945
#  22  23  7201    東証1部              日産自動車(株)  15:00   1074.5   4220715112
#  23  24  6954    東証1部              ファナック(株)  15:00    21915    204040771
#  24  25  6902    東証1部               (株)デンソー  15:00     5389    794068713
#  25  26  3382    東証1部    (株)セブン＆アイ・ホールディングス  15:00     4817    886441983
#  26  27  4063    東証1部             信越化学工業(株)  15:00     9951    427606693
#  27  28  4661    東証1部          (株)オリエンタルランド  15:00    11570    363690160
#  28  29  4452    東証1部                 花王(株)  15:00     8450    495000000
#  29  30  9020    東証1部            東日本旅客鉄道(株)  15:00    10615    385655500
#  30  31  6981    東証1部              (株)村田製作所  15:00    18155    225271427
#  31  32  6367    東証1部             ダイキン工業(株)  15:00    13470    293113973
#  32  33  8766    東証1部       東京海上ホールディングス(株)  15:00     5252    748024375
#  33  34  6501    東証1部              (株)日立製作所  15:00    772.2   4833463387
#  34  35  6752    東証1部             パナソニック(株)  15:00   1478.5   2453053497
#  35  36  4502    東証1部             武田薬品工業(株)  15:00     4524    794692395
#  36  37  4911    東証1部                (株)資生堂  15:00     8800    400000000
#  37  38  4503    東証1部            アステラス製薬(株)  15:00   1687.5   1979823175
#  38  39  5108    東証1部             (株)ブリヂストン  15:00     4328    761536421
#  39  40  8001    東証1部              伊藤忠商事(株)  15:00   1979.5   1662889504
#  40  41  4519    東証1部               中外製薬(株)  15:00     5790    559685889
#  41  42  8031    東証1部               三井物産(株)  15:00     1841   1742345627
#  42  43  6503    東証1部               三菱電機(株)  15:00     1474   2147201551
#  43  44  8035    東証1部           東京エレクトロン(株)  15:00    19000    165210911
#  44  45  6301    東証1部                   コマツ  15:00     3120    971967660
#  45  46  4568    東証1部               第一三共(株)  15:00     4237    709011343
#  46  47  7269    東証1部                スズキ(株)  15:00     6112    491018100
#  47  48  4578    東証1部         大塚ホールディングス(株)  15:00     5339    557835617
#  48  49  6273    東証1部                ＳＭＣ(株)  15:00    41420     67369359
#  49  50  2502    東証1部    アサヒグループホールディングス(株)  15:00     5647    483585862
#  50  順位   コード      市場                    名称    取引値  発行済み株式数    時価総額（百万円）
#
#          単元株数   掲示板 Unnamed: 9
#  0   23219490   100        掲示板
#  1   10739838   100        掲示板
#  2   10660166   100        掲示板
#  3    8759798   100        掲示板
#  4    8631379   100        掲示板
#  5    7740338   100        掲示板
#  6    7687795   100        掲示板
#  7    7263092   100        掲示板
#  8    6466385    50        掲示板
#  9    6075034   100        掲示板
#  10   6064000   100        掲示板
#  11   5849102   100        掲示板
#  12   5778000   100        掲示板
#  13   5436000   100        掲示板
#  14   5403392   100        掲示板
#  15   5208293   100        掲示板
#  16   5104334   100        掲示板
#  17   4962577   100        掲示板
#  18   4899027   100        掲示板
#  19   4807010   100        掲示板
#  20   4786877   100        掲示板
#  21   4720466   100        掲示板
#  22   4535158   100        掲示板
#  23   4471553   100        掲示板
#  24   4279236   100        掲示板
#  25   4269991   100        掲示板
#  26   4255114   100        掲示板
#  27   4207895   100        掲示板
#  28   4182750   100        掲示板
#  29   4093733   100        掲示板
#  30   4089803   100        掲示板
#  31   3948245   100        掲示板
#  32   3928624   100        掲示板
#  33   3732400  1000        掲示板
#  34   3626840   100        掲示板
#  35   3595188   100        掲示板
#  36   3520000   100        掲示板
#  37   3340952   100        掲示板
#  38   3295930   100        掲示板
#  39   3291690   100        掲示板
#  40   3240581   100        掲示板
#  41   3207658   100        掲示板
#  42   3164975   100        掲示板
#  43   3139007   100        掲示板
#  44   3032539   100        掲示板
#  45   3004081   100        掲示板
#  46   3001103   100        掲示板
#  47   2978284   100        掲示板
#  48   2790439   100        掲示板
#  49   2730809   100        掲示板
#  50      単元株数   掲示板        NaN  ]

# %% [markdown]
# ### 野菜のデータでも試してみる

# %%
url = 'https://www.seisen.maff.go.jp/seisen/bs04b040md001/BS04B040UC020SC001-Evt006.do'
fetched_dataframes = pd.io.html.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8327a5e438ff> in <module>()
#       1 url = 'https://www.seisen.maff.go.jp/seisen/bs04b040md001/BS04B040UC020SC001-Evt006.do'
# ----> 2 fetched_dataframes = pd.io.html.read_html(url)
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     904                   thousands=thousands, attrs=attrs, encoding=encoding,
#     905                   decimal=decimal, converters=converters, na_values=na_values,
# --> 906                   keep_default_na=keep_default_na)
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     741             break
#     742     else:
# --> 743         raise_with_traceback(retained)
#     744
#     745     ret = []
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     342         if traceback == Ellipsis:
#     343             _, _, traceback = sys.exc_info()
# --> 344         raise exc.with_traceback(traceback)
#     345 else:
#     346     # this version of raise is a syntax error in Python 3
#
# ValueError: No tables found

# %% [markdown]
# →表データをうまく読み込めてない

# %%
url = 'oroshi.html'
fetched_dataframes = pd.io.html.read_html(url, encoding ='utf-8')

# %%
fetched_dataframes
# Out:
# [                                                   0                  1    \
#  0                                 青果物卸売市場調査（日別調査） （野菜）  平成30年 6月 25日 （月）分
#  1                                             農林水産省統計部                NaN
#  2                                              都市名：横浜市                NaN
#  3    品目名／産地  数量(kg)  価格(円/kg)  対前日比  数量(％)  価格(％)  ...             品目名／産地
#  4                                               品目名／産地             数量(kg)
#  5                                                数量(％)              価格(％)
#  6                                                 野菜総量            1149087
#  7                                                  長　野             157571
#  8                                                  茨　城             142061
#  9                                                  群　馬             126119
#  10                                                 千　葉             115856
#  11                                                 佐　賀             100548
#  12                                                 青　森              56855
#  13                                                 福　島              46890
#  14                                                だいこん              68306
#  15                                                 青　森              45515
#  16                                                 北海道               8630
#  17                                                 千　葉               4770
#  18                                                  かぶ               7951
#  19                                                 埼　玉               3527
#  20                                                 青　森               2154
#  21                                                 千　葉               1709
#  22                                                にんじん              54314
#  23                                                 千　葉              46184
#  24                                                 ごぼう               4784
#  25                                                 青　森               2986
#  26                                                 群　馬                752
#  27                                                 鹿児島                648
#  28                                                れんこん                982
#  29                                                 熊　本                610
#  ..                                                 ...                ...
#  171                                                佐　賀              98220
#  172                                                香　川              10000
#  173                                               うち輸入               3630
#  174                                               にんにく               1513
#  175                                                青　森                508
#  176                                                千　葉                  4
#  177                                               うち輸入               1001
#  178                                               しょうが               8082
#  179                                                高　知               5905
#  180                                                熊　本                493
#  181                                                静　岡                344
#  182                                               うち輸入                985
#  183                                              生しいたけ               7067
#  184                                                秋　田               3190
#  185                                                岩　手               2537
#  186                                               うち輸入                286
#  187                                                なめこ               3342
#  188                                                長　野               1099
#  189                                                山　形                925
#  190                                                群　馬                572
#  191                                                新　潟                520
#  192                                              えのきだけ               6720
#  193                                                長　野               5502
#  194                                                しめじ               6407
#  195                                                長　野               4728
#  196                                                新　潟                914
#  197                                             その他の野菜              53549
#  198                                              輸入野菜計              35471
#  199                                             他の輸入野菜              11918
#  200  ［利用上の注意］  １．　上記の数値については、日々の確定値として収集してい  るが、その後...                NaN
#
#              2         3      4      5      6     7          8      9    \
#  0    平成30年6月26日       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  1           NaN       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  2           NaN       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  3        数量(kg)  価格(円/kg)   対前日比  数量(％)  価格(％)  野菜総量  1149087.0  242.0
#  4      価格(円/kg)      対前日比    NaN    NaN    NaN   NaN        NaN    NaN
#  5           NaN       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  6           242     105.1  109.5    NaN    NaN   NaN        NaN    NaN
#  7           182       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  8           237       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  9           222       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  10          204       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  11           92       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  12          163       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  13          276       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  14           95     106.4   99.0    NaN    NaN   NaN        NaN    NaN
#  15           96       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  16          110       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  17           53       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  18          143      80.9   99.3    NaN    NaN   NaN        NaN    NaN
#  19           90       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  20          220       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  21          163       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  22          117     138.9  104.5    NaN    NaN   NaN        NaN    NaN
#  23          118       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  24          399     134.0   95.5    NaN    NaN   NaN        NaN    NaN
#  25          375       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  26          394       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  27          588       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  28          893     110.8   78.9    NaN    NaN   NaN        NaN    NaN
#  29          988       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  ..          ...       ...    ...    ...    ...   ...        ...    ...
#  171          68       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  172          80       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  173          92      55.9  148.4    NaN    NaN   NaN        NaN    NaN
#  174         731      74.6   81.4    NaN    NaN   NaN        NaN    NaN
#  175        1522       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  176         988       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  177         329      78.1  101.5    NaN    NaN   NaN        NaN    NaN
#  178         712     113.9   95.3    NaN    NaN   NaN        NaN    NaN
#  179         728       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  180         878       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  181         952       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  182         322     110.3  100.6    NaN    NaN   NaN        NaN    NaN
#  183         905     125.5  101.2    NaN    NaN   NaN        NaN    NaN
#  184        1048       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  185         743       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  186         552     150.5   97.2    NaN    NaN   NaN        NaN    NaN
#  187         394      99.9  106.8    NaN    NaN   NaN        NaN    NaN
#  188         316       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  189         433       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  190         409       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  191         501       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  192         222      88.6  113.8    NaN    NaN   NaN        NaN    NaN
#  193         226       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  194         332      73.0   99.7    NaN    NaN   NaN        NaN    NaN
#  195         345       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  196         318       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#  197         561     118.5   94.8    NaN    NaN   NaN        NaN    NaN
#  198         190      82.3  113.1    NaN    NaN   NaN        NaN    NaN
#  199         274      90.3  111.8    NaN    NaN   NaN        NaN    NaN
#  200         NaN       NaN    NaN    NaN    NaN   NaN        NaN    NaN
#
#                             ...                              968    969   970  \
#  0                          ...                              NaN    NaN   NaN
#  1                          ...                              NaN    NaN   NaN
#  2                          ...                              NaN    NaN   NaN
#  3                          ...                          35471.0  190.0  82.3
#  4                          ...                              NaN    NaN   NaN
#  5                          ...                              NaN    NaN   NaN
#  6                          ...                              NaN    NaN   NaN
#  7                          ...                              NaN    NaN   NaN
#  8                          ...                              NaN    NaN   NaN
#  9                          ...                              NaN    NaN   NaN
#  10                         ...                              NaN    NaN   NaN
#  11                         ...                              NaN    NaN   NaN
#  12                         ...                              NaN    NaN   NaN
#  13                         ...                              NaN    NaN   NaN
#  14                         ...                              NaN    NaN   NaN
#  15                         ...                              NaN    NaN   NaN
#  16                         ...                              NaN    NaN   NaN
#  17                         ...                              NaN    NaN   NaN
#  18                         ...                              NaN    NaN   NaN
#  19                         ...                              NaN    NaN   NaN
#  20                         ...                              NaN    NaN   NaN
#  21                         ...                              NaN    NaN   NaN
#  22                         ...                              NaN    NaN   NaN
#  23                         ...                              NaN    NaN   NaN
#  24                         ...                              NaN    NaN   NaN
#  25                         ...                              NaN    NaN   NaN
#  26                         ...                              NaN    NaN   NaN
#  27                         ...                              NaN    NaN   NaN
#  28                         ...                              NaN    NaN   NaN
#  29                         ...                              NaN    NaN   NaN
#  ..                         ...                              ...    ...   ...
#  171                        ...                              NaN    NaN   NaN
#  172                        ...                              NaN    NaN   NaN
#  173                        ...                              NaN    NaN   NaN
#  174                        ...                              NaN    NaN   NaN
#  175                        ...                              NaN    NaN   NaN
#  176                        ...                              NaN    NaN   NaN
#  177                        ...                              NaN    NaN   NaN
#  178                        ...                              NaN    NaN   NaN
#  179                        ...                              NaN    NaN   NaN
#  180                        ...                              NaN    NaN   NaN
#  181                        ...                              NaN    NaN   NaN
#  182                        ...                              NaN    NaN   NaN
#  183                        ...                              NaN    NaN   NaN
#  184                        ...                              NaN    NaN   NaN
#  185                        ...                              NaN    NaN   NaN
#  186                        ...                              NaN    NaN   NaN
#  187                        ...                              NaN    NaN   NaN
#  188                        ...                              NaN    NaN   NaN
#  189                        ...                              NaN    NaN   NaN
#  190                        ...                              NaN    NaN   NaN
#  191                        ...                              NaN    NaN   NaN
#  192                        ...                              NaN    NaN   NaN
#  193                        ...                              NaN    NaN   NaN
#  194                        ...                              NaN    NaN   NaN
#  195                        ...                              NaN    NaN   NaN
#  196                        ...                              NaN    NaN   NaN
#  197                        ...                              NaN    NaN   NaN
#  198                        ...                              NaN    NaN   NaN
#  199                        ...                              NaN    NaN   NaN
#  200                        ...                              NaN    NaN   NaN
#
#         971     972      973    974   975    976  \
#  0      NaN     NaN      NaN    NaN   NaN    NaN
#  1      NaN     NaN      NaN    NaN   NaN    NaN
#  2      NaN     NaN      NaN    NaN   NaN    NaN
#  3    113.1  他の輸入野菜  11918.0  274.0  90.3  111.8
#  4      NaN     NaN      NaN    NaN   NaN    NaN
#  5      NaN     NaN      NaN    NaN   NaN    NaN
#  6      NaN     NaN      NaN    NaN   NaN    NaN
#  7      NaN     NaN      NaN    NaN   NaN    NaN
#  8      NaN     NaN      NaN    NaN   NaN    NaN
#  9      NaN     NaN      NaN    NaN   NaN    NaN
#  10     NaN     NaN      NaN    NaN   NaN    NaN
#  11     NaN     NaN      NaN    NaN   NaN    NaN
#  12     NaN     NaN      NaN    NaN   NaN    NaN
#  13     NaN     NaN      NaN    NaN   NaN    NaN
#  14     NaN     NaN      NaN    NaN   NaN    NaN
#  15     NaN     NaN      NaN    NaN   NaN    NaN
#  16     NaN     NaN      NaN    NaN   NaN    NaN
#  17     NaN     NaN      NaN    NaN   NaN    NaN
#  18     NaN     NaN      NaN    NaN   NaN    NaN
#  19     NaN     NaN      NaN    NaN   NaN    NaN
#  20     NaN     NaN      NaN    NaN   NaN    NaN
#  21     NaN     NaN      NaN    NaN   NaN    NaN
#  22     NaN     NaN      NaN    NaN   NaN    NaN
#  23     NaN     NaN      NaN    NaN   NaN    NaN
#  24     NaN     NaN      NaN    NaN   NaN    NaN
#  25     NaN     NaN      NaN    NaN   NaN    NaN
#  26     NaN     NaN      NaN    NaN   NaN    NaN
#  27     NaN     NaN      NaN    NaN   NaN    NaN
#  28     NaN     NaN      NaN    NaN   NaN    NaN
#  29     NaN     NaN      NaN    NaN   NaN    NaN
#  ..     ...     ...      ...    ...   ...    ...
#  171    NaN     NaN      NaN    NaN   NaN    NaN
#  172    NaN     NaN      NaN    NaN   NaN    NaN
#  173    NaN     NaN      NaN    NaN   NaN    NaN
#  174    NaN     NaN      NaN    NaN   NaN    NaN
#  175    NaN     NaN      NaN    NaN   NaN    NaN
#  176    NaN     NaN      NaN    NaN   NaN    NaN
#  177    NaN     NaN      NaN    NaN   NaN    NaN
#  178    NaN     NaN      NaN    NaN   NaN    NaN
#  179    NaN     NaN      NaN    NaN   NaN    NaN
#  180    NaN     NaN      NaN    NaN   NaN    NaN
#  181    NaN     NaN      NaN    NaN   NaN    NaN
#  182    NaN     NaN      NaN    NaN   NaN    NaN
#  183    NaN     NaN      NaN    NaN   NaN    NaN
#  184    NaN     NaN      NaN    NaN   NaN    NaN
#  185    NaN     NaN      NaN    NaN   NaN    NaN
#  186    NaN     NaN      NaN    NaN   NaN    NaN
#  187    NaN     NaN      NaN    NaN   NaN    NaN
#  188    NaN     NaN      NaN    NaN   NaN    NaN
#  189    NaN     NaN      NaN    NaN   NaN    NaN
#  190    NaN     NaN      NaN    NaN   NaN    NaN
#  191    NaN     NaN      NaN    NaN   NaN    NaN
#  192    NaN     NaN      NaN    NaN   NaN    NaN
#  193    NaN     NaN      NaN    NaN   NaN    NaN
#  194    NaN     NaN      NaN    NaN   NaN    NaN
#  195    NaN     NaN      NaN    NaN   NaN    NaN
#  196    NaN     NaN      NaN    NaN   NaN    NaN
#  197    NaN     NaN      NaN    NaN   NaN    NaN
#  198    NaN     NaN      NaN    NaN   NaN    NaN
#  199    NaN     NaN      NaN    NaN   NaN    NaN
#  200    NaN     NaN      NaN    NaN   NaN    NaN
#
#                                                     977
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    ［利用上の注意］  １．　上記の数値については、日々の確定値として収集してい  るが、その後...
#  4                                                  NaN
#  5                                                  NaN
#  6                                                  NaN
#  7                                                  NaN
#  8                                                  NaN
#  9                                                  NaN
#  10                                                 NaN
#  11                                                 NaN
#  12                                                 NaN
#  13                                                 NaN
#  14                                                 NaN
#  15                                                 NaN
#  16                                                 NaN
#  17                                                 NaN
#  18                                                 NaN
#  19                                                 NaN
#  20                                                 NaN
#  21                                                 NaN
#  22                                                 NaN
#  23                                                 NaN
#  24                                                 NaN
#  25                                                 NaN
#  26                                                 NaN
#  27                                                 NaN
#  28                                                 NaN
#  29                                                 NaN
#  ..                                                 ...
#  171                                                NaN
#  172                                                NaN
#  173                                                NaN
#  174                                                NaN
#  175                                                NaN
#  176                                                NaN
#  177                                                NaN
#  178                                                NaN
#  179                                                NaN
#  180                                                NaN
#  181                                                NaN
#  182                                                NaN
#  183                                                NaN
#  184                                                NaN
#  185                                                NaN
#  186                                                NaN
#  187                                                NaN
#  188                                                NaN
#  189                                                NaN
#  190                                                NaN
#  191                                                NaN
#  192                                                NaN
#  193                                                NaN
#  194                                                NaN
#  195                                                NaN
#  196                                                NaN
#  197                                                NaN
#  198                                                NaN
#  199                                                NaN
#  200                                                NaN
#
#  [201 rows x 978 columns],
#                                                       0        1         2  \
#  0                                               品目名／産地   数量(kg)  価格(円/kg)
#  1                                                数量(％)    価格(％)       NaN
#  2                                                 野菜総量  1149087       242
#  3                                                  長　野   157571       182
#  4                                                  茨　城   142061       237
#  5                                                  群　馬   126119       222
#  6                                                  千　葉   115856       204
#  7                                                  佐　賀   100548        92
#  8                                                  青　森    56855       163
#  9                                                  福　島    46890       276
#  10                                                だいこん    68306        95
#  11                                                 青　森    45515        96
#  12                                                 北海道     8630       110
#  13                                                 千　葉     4770        53
#  14                                                  かぶ     7951       143
#  15                                                 埼　玉     3527        90
#  16                                                 青　森     2154       220
#  17                                                 千　葉     1709       163
#  18                                                にんじん    54314       117
#  19                                                 千　葉    46184       118
#  20                                                 ごぼう     4784       399
#  21                                                 青　森     2986       375
#  22                                                 群　馬      752       394
#  23                                                 鹿児島      648       588
#  24                                                れんこん      982       893
#  25                                                 熊　本      610       988
#  26                                                 徳　島      272       581
#  27                                                はくさい    57700        79
#  28                                                 長　野    38550        84
#  29                                                 茨　城    12500        70
#  ..                                                 ...      ...       ...
#  167                                                佐　賀    98220        68
#  168                                                香　川    10000        80
#  169                                               うち輸入     3630        92
#  170                                               にんにく     1513       731
#  171                                                青　森      508      1522
#  172                                                千　葉        4       988
#  173                                               うち輸入     1001       329
#  174                                               しょうが     8082       712
#  175                                                高　知     5905       728
#  176                                                熊　本      493       878
#  177                                                静　岡      344       952
#  178                                               うち輸入      985       322
#  179                                              生しいたけ     7067       905
#  180                                                秋　田     3190      1048
#  181                                                岩　手     2537       743
#  182                                               うち輸入      286       552
#  183                                                なめこ     3342       394
#  184                                                長　野     1099       316
#  185                                                山　形      925       433
#  186                                                群　馬      572       409
#  187                                                新　潟      520       501
#  188                                              えのきだけ     6720       222
#  189                                                長　野     5502       226
#  190                                                しめじ     6407       332
#  191                                                長　野     4728       345
#  192                                                新　潟      914       318
#  193                                             その他の野菜    53549       561
#  194                                              輸入野菜計    35471       190
#  195                                             他の輸入野菜    11918       274
#  196  ［利用上の注意］  １．　上記の数値については、日々の確定値として収集してい  るが、その後...      NaN       NaN
#
#           3      4
#  0     対前日比    NaN
#  1      NaN    NaN
#  2    105.1  109.5
#  3      NaN    NaN
#  4      NaN    NaN
#  5      NaN    NaN
#  6      NaN    NaN
#  7      NaN    NaN
#  8      NaN    NaN
#  9      NaN    NaN
#  10   106.4   99.0
#  11     NaN    NaN
#  12     NaN    NaN
#  13     NaN    NaN
#  14    80.9   99.3
#  15     NaN    NaN
#  16     NaN    NaN
#  17     NaN    NaN
#  18   138.9  104.5
#  19     NaN    NaN
#  20   134.0   95.5
#  21     NaN    NaN
#  22     NaN    NaN
#  23     NaN    NaN
#  24   110.8   78.9
#  25     NaN    NaN
#  26     NaN    NaN
#  27   111.1   88.8
#  28     NaN    NaN
#  29     NaN    NaN
#  ..     ...    ...
#  167    NaN    NaN
#  168    NaN    NaN
#  169   55.9  148.4
#  170   74.6   81.4
#  171    NaN    NaN
#  172    NaN    NaN
#  173   78.1  101.5
#  174  113.9   95.3
#  175    NaN    NaN
#  176    NaN    NaN
#  177    NaN    NaN
#  178  110.3  100.6
#  179  125.5  101.2
#  180    NaN    NaN
#  181    NaN    NaN
#  182  150.5   97.2
#  183   99.9  106.8
#  184    NaN    NaN
#  185    NaN    NaN
#  186    NaN    NaN
#  187    NaN    NaN
#  188   88.6  113.8
#  189    NaN    NaN
#  190   73.0   99.7
#  191    NaN    NaN
#  192    NaN    NaN
#  193  118.5   94.8
#  194   82.3  113.1
#  195   90.3  111.8
#  196    NaN    NaN
#
#  [197 rows x 5 columns]]

# %% [markdown]
# →サイトに問題があったので保存したhtmlで対応

# %% [markdown]
# ## HTMLからデータを取得し、エクセルファイルに変換（beautifulsoup+csv)<br>
# https://qiita.com/hujuu/items/b0339404b8b0460087f9

# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
# #HTMLの取得(そのままやると今回の場合システムエラーになるので回避する)
# target_url = 'https://www.seisen.maff.go.jp/seisen/bs04b040md001/BS04B040UC020SC001-Evt006.do'
# r = requests.get(target_url)         #requestsを使って、webから取得

# %%
#htmlパース用のオブジェクト作成(上記の通り今回は保存済み　HTMLを使用)
# soup = BeautifulSoup(r.text, 'lxml') #要素を抽出

soup = BeautifulSoup(open('oroshi.html', encoding='utf-8'), 'html.parser')

# %%
#csvfileを指定
csvFile = open("oroshi.csv","wt",newline = '', encoding = "shift-jis")
writer = csv.writer(csvFile)

#Tableを指定
tables = soup.find_all("table")
for table in tables:
    rows = [row for row in table.find_all('tr')]
    
try:
    for row in rows:
        csvRow = []
        for cell in row.find_all(['td','th']):
            csvRow.append(cell.get_text())
            print(csvRow)
        writer.writerow(csvRow)
        
finally:
    csvFile.close()
# Out:
# ['品目名／産地']
# ['品目名／産地', '数量(kg)']
# ['品目名／産地', '数量(kg)', '価格(円/kg)']
# ['品目名／産地', '数量(kg)', '価格(円/kg)', '対前日比']
# ['数量(％)']
# ['数量(％)', '価格(％)']
# ['野菜総量']
# ['野菜総量', '1,149,087']
# ['野菜総量', '1,149,087', '242']
# ['野菜総量', '1,149,087', '242', '105.1']
# ['野菜総量', '1,149,087', '242', '105.1', '109.5']
# ['長\u3000野']
# ['長\u3000野', '157,571']
# ['長\u3000野', '157,571', '182']
# ['長\u3000野', '157,571', '182', '']
# ['長\u3000野', '157,571', '182', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '142,061']
# ['茨\u3000城', '142,061', '237']
# ['茨\u3000城', '142,061', '237', '']
# ['茨\u3000城', '142,061', '237', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '126,119']
# ['群\u3000馬', '126,119', '222']
# ['群\u3000馬', '126,119', '222', '']
# ['群\u3000馬', '126,119', '222', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '115,856']
# ['千\u3000葉', '115,856', '204']
# ['千\u3000葉', '115,856', '204', '']
# ['千\u3000葉', '115,856', '204', '', '']
# ['佐\u3000賀']
# ['佐\u3000賀', '100,548']
# ['佐\u3000賀', '100,548', '92']
# ['佐\u3000賀', '100,548', '92', '']
# ['佐\u3000賀', '100,548', '92', '', '']
# ['青\u3000森']
# ['青\u3000森', '56,855']
# ['青\u3000森', '56,855', '163']
# ['青\u3000森', '56,855', '163', '']
# ['青\u3000森', '56,855', '163', '', '']
# ['福\u3000島']
# ['福\u3000島', '46,890']
# ['福\u3000島', '46,890', '276']
# ['福\u3000島', '46,890', '276', '']
# ['福\u3000島', '46,890', '276', '', '']
# ['だいこん']
# ['だいこん', '68,306']
# ['だいこん', '68,306', '95']
# ['だいこん', '68,306', '95', '106.4']
# ['だいこん', '68,306', '95', '106.4', '99.0']
# ['青\u3000森']
# ['青\u3000森', '45,515']
# ['青\u3000森', '45,515', '96']
# ['青\u3000森', '45,515', '96', '']
# ['青\u3000森', '45,515', '96', '', '']
# ['北海道']
# ['北海道', '8,630']
# ['北海道', '8,630', '110']
# ['北海道', '8,630', '110', '']
# ['北海道', '8,630', '110', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '4,770']
# ['千\u3000葉', '4,770', '53']
# ['千\u3000葉', '4,770', '53', '']
# ['千\u3000葉', '4,770', '53', '', '']
# ['かぶ']
# ['かぶ', '7,951']
# ['かぶ', '7,951', '143']
# ['かぶ', '7,951', '143', '80.9']
# ['かぶ', '7,951', '143', '80.9', '99.3']
# ['埼\u3000玉']
# ['埼\u3000玉', '3,527']
# ['埼\u3000玉', '3,527', '90']
# ['埼\u3000玉', '3,527', '90', '']
# ['埼\u3000玉', '3,527', '90', '', '']
# ['青\u3000森']
# ['青\u3000森', '2,154']
# ['青\u3000森', '2,154', '220']
# ['青\u3000森', '2,154', '220', '']
# ['青\u3000森', '2,154', '220', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '1,709']
# ['千\u3000葉', '1,709', '163']
# ['千\u3000葉', '1,709', '163', '']
# ['千\u3000葉', '1,709', '163', '', '']
# ['にんじん']
# ['にんじん', '54,314']
# ['にんじん', '54,314', '117']
# ['にんじん', '54,314', '117', '138.9']
# ['にんじん', '54,314', '117', '138.9', '104.5']
# ['千\u3000葉']
# ['千\u3000葉', '46,184']
# ['千\u3000葉', '46,184', '118']
# ['千\u3000葉', '46,184', '118', '']
# ['千\u3000葉', '46,184', '118', '', '']
# ['ごぼう']
# ['ごぼう', '4,784']
# ['ごぼう', '4,784', '399']
# ['ごぼう', '4,784', '399', '134.0']
# ['ごぼう', '4,784', '399', '134.0', '95.5']
# ['青\u3000森']
# ['青\u3000森', '2,986']
# ['青\u3000森', '2,986', '375']
# ['青\u3000森', '2,986', '375', '']
# ['青\u3000森', '2,986', '375', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '752']
# ['群\u3000馬', '752', '394']
# ['群\u3000馬', '752', '394', '']
# ['群\u3000馬', '752', '394', '', '']
# ['鹿児島']
# ['鹿児島', '648']
# ['鹿児島', '648', '588']
# ['鹿児島', '648', '588', '']
# ['鹿児島', '648', '588', '', '']
# ['れんこん']
# ['れんこん', '982']
# ['れんこん', '982', '893']
# ['れんこん', '982', '893', '110.8']
# ['れんこん', '982', '893', '110.8', '78.9']
# ['熊\u3000本']
# ['熊\u3000本', '610']
# ['熊\u3000本', '610', '988']
# ['熊\u3000本', '610', '988', '']
# ['熊\u3000本', '610', '988', '', '']
# ['徳\u3000島']
# ['徳\u3000島', '272']
# ['徳\u3000島', '272', '581']
# ['徳\u3000島', '272', '581', '']
# ['徳\u3000島', '272', '581', '', '']
# ['はくさい']
# ['はくさい', '57,700']
# ['はくさい', '57,700', '79']
# ['はくさい', '57,700', '79', '111.1']
# ['はくさい', '57,700', '79', '111.1', '88.8']
# ['長\u3000野']
# ['長\u3000野', '38,550']
# ['長\u3000野', '38,550', '84']
# ['長\u3000野', '38,550', '84', '']
# ['長\u3000野', '38,550', '84', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '12,500']
# ['茨\u3000城', '12,500', '70']
# ['茨\u3000城', '12,500', '70', '']
# ['茨\u3000城', '12,500', '70', '', '']
# ['みずな']
# ['みずな', '4,757']
# ['みずな', '4,757', '448']
# ['みずな', '4,757', '448', '98.4']
# ['みずな', '4,757', '448', '98.4', '108.0']
# ['茨\u3000城']
# ['茨\u3000城', '4,523']
# ['茨\u3000城', '4,523', '449']
# ['茨\u3000城', '4,523', '449', '']
# ['茨\u3000城', '4,523', '449', '', '']
# ['こまつな']
# ['こまつな', '14,012']
# ['こまつな', '14,012', '267']
# ['こまつな', '14,012', '267', '134.7']
# ['こまつな', '14,012', '267', '134.7', '100.4']
# ['茨\u3000城']
# ['茨\u3000城', '8,850']
# ['茨\u3000城', '8,850', '263']
# ['茨\u3000城', '8,850', '263', '']
# ['茨\u3000城', '8,850', '263', '', '']
# ['埼\u3000玉']
# ['埼\u3000玉', '1,772']
# ['埼\u3000玉', '1,772', '317']
# ['埼\u3000玉', '1,772', '317', '']
# ['埼\u3000玉', '1,772', '317', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '1,688']
# ['群\u3000馬', '1,688', '260']
# ['群\u3000馬', '1,688', '260', '']
# ['群\u3000馬', '1,688', '260', '', '']
# ['その他の菜類']
# ['その他の菜類', '275']
# ['その他の菜類', '275', '317']
# ['その他の菜類', '275', '317', '60.2']
# ['その他の菜類', '275', '317', '60.2', '112.4']
# ['ちんげんさい']
# ['ちんげんさい', '4,358']
# ['ちんげんさい', '4,358', '296']
# ['ちんげんさい', '4,358', '296', '123.4']
# ['ちんげんさい', '4,358', '296', '123.4', '112.1']
# ['茨\u3000城']
# ['茨\u3000城', '3,732']
# ['茨\u3000城', '3,732', '299']
# ['茨\u3000城', '3,732', '299', '']
# ['茨\u3000城', '3,732', '299', '', '']
# ['キャベツ']
# ['キャベツ', '119,255']
# ['キャベツ', '119,255', '89']
# ['キャベツ', '119,255', '89', '99.8']
# ['キャベツ', '119,255', '89', '99.8', '91.8']
# ['群\u3000馬']
# ['群\u3000馬', '49,150']
# ['群\u3000馬', '49,150', '101']
# ['群\u3000馬', '49,150', '101', '']
# ['群\u3000馬', '49,150', '101', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '37,760']
# ['茨\u3000城', '37,760', '79']
# ['茨\u3000城', '37,760', '79', '']
# ['茨\u3000城', '37,760', '79', '', '']
# ['秋\u3000田']
# ['秋\u3000田', '13,450']
# ['秋\u3000田', '13,450', '90']
# ['秋\u3000田', '13,450', '90', '']
# ['秋\u3000田', '13,450', '90', '', '']
# ['ほうれんそう']
# ['ほうれんそう', '19,541']
# ['ほうれんそう', '19,541', '494']
# ['ほうれんそう', '19,541', '494', '131.7']
# ['ほうれんそう', '19,541', '494', '131.7', '100.8']
# ['群\u3000馬']
# ['群\u3000馬', '10,540']
# ['群\u3000馬', '10,540', '462']
# ['群\u3000馬', '10,540', '462', '']
# ['群\u3000馬', '10,540', '462', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '3,740']
# ['茨\u3000城', '3,740', '504']
# ['茨\u3000城', '3,740', '504', '']
# ['茨\u3000城', '3,740', '504', '', '']
# ['岩\u3000手']
# ['岩\u3000手', '2,592']
# ['岩\u3000手', '2,592', '582']
# ['岩\u3000手', '2,592', '582', '']
# ['岩\u3000手', '2,592', '582', '', '']
# ['ねぎ']
# ['ねぎ', '29,657']
# ['ねぎ', '29,657', '408']
# ['ねぎ', '29,657', '408', '101.9']
# ['ねぎ', '29,657', '408', '101.9', '95.1']
# ['茨\u3000城']
# ['茨\u3000城', '15,141']
# ['茨\u3000城', '15,141', '370']
# ['茨\u3000城', '15,141', '370', '']
# ['茨\u3000城', '15,141', '370', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '5,964']
# ['千\u3000葉', '5,964', '400']
# ['千\u3000葉', '5,964', '400', '']
# ['千\u3000葉', '5,964', '400', '', '']
# ['北海道']
# ['北海道', '1,800']
# ['北海道', '1,800', '550']
# ['北海道', '1,800', '550', '']
# ['北海道', '1,800', '550', '', '']
# ['静\u3000岡']
# ['静\u3000岡', '1,011']
# ['静\u3000岡', '1,011', '674']
# ['静\u3000岡', '1,011', '674', '']
# ['静\u3000岡', '1,011', '674', '', '']
# ['ふき']
# ['ふき', '2']
# ['ふき', '2', '378']
# ['ふき', '2', '378', '20.0']
# ['ふき', '2', '378', '20.0', '109.2']
# ['山\u3000形']
# ['山\u3000形', '2']
# ['山\u3000形', '2', '378']
# ['山\u3000形', '2', '378', '']
# ['山\u3000形', '2', '378', '', '']
# ['みつば']
# ['みつば', '1,557']
# ['みつば', '1,557', '288']
# ['みつば', '1,557', '288', '90.1']
# ['みつば', '1,557', '288', '90.1', '104.0']
# ['千\u3000葉']
# ['千\u3000葉', '550']
# ['千\u3000葉', '550', '162']
# ['千\u3000葉', '550', '162', '']
# ['千\u3000葉', '550', '162', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '370']
# ['茨\u3000城', '370', '385']
# ['茨\u3000城', '370', '385', '']
# ['茨\u3000城', '370', '385', '', '']
# ['埼\u3000玉']
# ['埼\u3000玉', '280']
# ['埼\u3000玉', '280', '295']
# ['埼\u3000玉', '280', '295', '']
# ['埼\u3000玉', '280', '295', '', '']
# ['愛\u3000知']
# ['愛\u3000知', '203']
# ['愛\u3000知', '203', '391']
# ['愛\u3000知', '203', '391', '']
# ['愛\u3000知', '203', '391', '', '']
# ['しゅんぎく']
# ['しゅんぎく', '499']
# ['しゅんぎく', '499', '597']
# ['しゅんぎく', '499', '597', '83.2']
# ['しゅんぎく', '499', '597', '83.2', '85.3']
# ['茨\u3000城']
# ['茨\u3000城', '149']
# ['茨\u3000城', '149', '550']
# ['茨\u3000城', '149', '550', '']
# ['茨\u3000城', '149', '550', '', '']
# ['岩\u3000手']
# ['岩\u3000手', '138']
# ['岩\u3000手', '138', '493']
# ['岩\u3000手', '138', '493', '']
# ['岩\u3000手', '138', '493', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '126']
# ['千\u3000葉', '126', '698']
# ['千\u3000葉', '126', '698', '']
# ['千\u3000葉', '126', '698', '', '']
# ['にら']
# ['にら', '6,605']
# ['にら', '6,605', '606']
# ['にら', '6,605', '606', '90.9']
# ['にら', '6,605', '606', '90.9', '99.5']
# ['高\u3000知']
# ['高\u3000知', '2,075']
# ['高\u3000知', '2,075', '608']
# ['高\u3000知', '2,075', '608', '']
# ['高\u3000知', '2,075', '608', '', '']
# ['栃\u3000木']
# ['栃\u3000木', '1,687']
# ['栃\u3000木', '1,687', '648']
# ['栃\u3000木', '1,687', '648', '']
# ['栃\u3000木', '1,687', '648', '', '']
# ['山\u3000形']
# ['山\u3000形', '992']
# ['山\u3000形', '992', '602']
# ['山\u3000形', '992', '602', '']
# ['山\u3000形', '992', '602', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '940']
# ['茨\u3000城', '940', '546']
# ['茨\u3000城', '940', '546', '']
# ['茨\u3000城', '940', '546', '', '']
# ['セルリー']
# ['セルリー', '5,599']
# ['セルリー', '5,599', '273']
# ['セルリー', '5,599', '273', '152.8']
# ['セルリー', '5,599', '273', '152.8', '95.5']
# ['長\u3000野']
# ['長\u3000野', '5,480']
# ['長\u3000野', '5,480', '272']
# ['長\u3000野', '5,480', '272', '']
# ['長\u3000野', '5,480', '272', '', '']
# ['アスパラガス']
# ['アスパラガス', '5,018']
# ['アスパラガス', '5,018', '1,428']
# ['アスパラガス', '5,018', '1,428', '134.5']
# ['アスパラガス', '5,018', '1,428', '134.5', '100.1']
# ['佐\u3000賀']
# ['佐\u3000賀', '1,445']
# ['佐\u3000賀', '1,445', '1,426']
# ['佐\u3000賀', '1,445', '1,426', '']
# ['佐\u3000賀', '1,445', '1,426', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '1,052']
# ['熊\u3000本', '1,052', '1,365']
# ['熊\u3000本', '1,052', '1,365', '']
# ['熊\u3000本', '1,052', '1,365', '', '']
# ['栃\u3000木']
# ['栃\u3000木', '761']
# ['栃\u3000木', '761', '1,518']
# ['栃\u3000木', '761', '1,518', '']
# ['栃\u3000木', '761', '1,518', '', '']
# ['秋\u3000田']
# ['秋\u3000田', '417']
# ['秋\u3000田', '417', '1,458']
# ['秋\u3000田', '417', '1,458', '']
# ['秋\u3000田', '417', '1,458', '', '']
# ['長\u3000崎']
# ['長\u3000崎', '405']
# ['長\u3000崎', '405', '1,381']
# ['長\u3000崎', '405', '1,381', '']
# ['長\u3000崎', '405', '1,381', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '2']
# ['\u3000\u3000うち輸入', '2', '3,240']
# ['\u3000\u3000うち輸入', '2', '3,240', '1.8']
# ['\u3000\u3000うち輸入', '2', '3,240', '1.8', '274.8']
# ['カリフラワー']
# ['カリフラワー', '1,824']
# ['カリフラワー', '1,824', '283']
# ['カリフラワー', '1,824', '283', '77.0']
# ['カリフラワー', '1,824', '283', '77.0', '112.7']
# ['長\u3000野']
# ['長\u3000野', '1,326']
# ['長\u3000野', '1,326', '339']
# ['長\u3000野', '1,326', '339', '']
# ['長\u3000野', '1,326', '339', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '498']
# ['茨\u3000城', '498', '134']
# ['茨\u3000城', '498', '134', '']
# ['茨\u3000城', '498', '134', '', '']
# ['ブロッコリー']
# ['ブロッコリー', '17,101']
# ['ブロッコリー', '17,101', '490']
# ['ブロッコリー', '17,101', '490', '103.9']
# ['ブロッコリー', '17,101', '490', '103.9', '101.4']
# ['長\u3000野']
# ['長\u3000野', '13,148']
# ['長\u3000野', '13,148', '505']
# ['長\u3000野', '13,148', '505', '']
# ['長\u3000野', '13,148', '505', '', '']
# ['北海道']
# ['北海道', '3,024']
# ['北海道', '3,024', '459']
# ['北海道', '3,024', '459', '']
# ['北海道', '3,024', '459', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '509']
# ['\u3000\u3000うち輸入', '509', '375']
# ['\u3000\u3000うち輸入', '509', '375', '101.8']
# ['\u3000\u3000うち輸入', '509', '375', '101.8', '103.6']
# ['レタス']
# ['レタス', '111,327']
# ['レタス', '111,327', '141']
# ['レタス', '111,327', '141', '147.9']
# ['レタス', '111,327', '141', '147.9', '96.6']
# ['長\u3000野']
# ['長\u3000野', '83,253']
# ['長\u3000野', '83,253', '142']
# ['長\u3000野', '83,253', '142', '']
# ['長\u3000野', '83,253', '142', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '22,822']
# ['群\u3000馬', '22,822', '124']
# ['群\u3000馬', '22,822', '124', '']
# ['群\u3000馬', '22,822', '124', '', '']
# ['パセリ']
# ['パセリ', '507']
# ['パセリ', '507', '1,084']
# ['パセリ', '507', '1,084', '110.5']
# ['パセリ', '507', '1,084', '110.5', '95.3']
# ['千\u3000葉']
# ['千\u3000葉', '230']
# ['千\u3000葉', '230', '780']
# ['千\u3000葉', '230', '780', '']
# ['千\u3000葉', '230', '780', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '159']
# ['茨\u3000城', '159', '1,205']
# ['茨\u3000城', '159', '1,205', '']
# ['茨\u3000城', '159', '1,205', '', '']
# ['長\u3000野']
# ['長\u3000野', '82']
# ['長\u3000野', '82', '1,168']
# ['長\u3000野', '82', '1,168', '']
# ['長\u3000野', '82', '1,168', '', '']
# ['きゅうり']
# ['きゅうり', '76,654']
# ['きゅうり', '76,654', '304']
# ['きゅうり', '76,654', '304', '172.0']
# ['きゅうり', '76,654', '304', '172.0', '87.6']
# ['福\u3000島']
# ['福\u3000島', '27,390']
# ['福\u3000島', '27,390', '331']
# ['福\u3000島', '27,390', '331', '']
# ['福\u3000島', '27,390', '331', '', '']
# ['埼\u3000玉']
# ['埼\u3000玉', '8,988']
# ['埼\u3000玉', '8,988', '277']
# ['埼\u3000玉', '8,988', '277', '']
# ['埼\u3000玉', '8,988', '277', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '7,325']
# ['群\u3000馬', '7,325', '290']
# ['群\u3000馬', '7,325', '290', '']
# ['群\u3000馬', '7,325', '290', '', '']
# ['山\u3000形']
# ['山\u3000形', '6,641']
# ['山\u3000形', '6,641', '359']
# ['山\u3000形', '6,641', '359', '']
# ['山\u3000形', '6,641', '359', '', '']
# ['栃\u3000木']
# ['栃\u3000木', '4,220']
# ['栃\u3000木', '4,220', '282']
# ['栃\u3000木', '4,220', '282', '']
# ['栃\u3000木', '4,220', '282', '', '']
# ['かぼちゃ']
# ['かぼちゃ', '29,737']
# ['かぼちゃ', '29,737', '196']
# ['かぼちゃ', '29,737', '196', '87.3']
# ['かぼちゃ', '29,737', '196', '87.3', '105.4']
# ['神奈川']
# ['神奈川', '3,674']
# ['神奈川', '3,674', '373']
# ['神奈川', '3,674', '373', '']
# ['神奈川', '3,674', '373', '', '']
# ['鹿児島']
# ['鹿児島', '3,190']
# ['鹿児島', '3,190', '179']
# ['鹿児島', '3,190', '179', '']
# ['鹿児島', '3,190', '179', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '2,210']
# ['群\u3000馬', '2,210', '313']
# ['群\u3000馬', '2,210', '313', '']
# ['群\u3000馬', '2,210', '313', '', '']
# ['栃\u3000木']
# ['栃\u3000木', '1,392']
# ['栃\u3000木', '1,392', '301']
# ['栃\u3000木', '1,392', '301', '']
# ['栃\u3000木', '1,392', '301', '', '']
# ['長\u3000野']
# ['長\u3000野', '1,285']
# ['長\u3000野', '1,285', '330']
# ['長\u3000野', '1,285', '330', '']
# ['長\u3000野', '1,285', '330', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '16,913']
# ['\u3000\u3000うち輸入', '16,913', '121']
# ['\u3000\u3000うち輸入', '16,913', '121', '83.6']
# ['\u3000\u3000うち輸入', '16,913', '121', '83.6', '100.8']
# ['なす']
# ['なす', '37,212']
# ['なす', '37,212', '403']
# ['なす', '37,212', '403', '96.5']
# ['なす', '37,212', '403', '96.5', '105.2']
# ['群\u3000馬']
# ['群\u3000馬', '7,760']
# ['群\u3000馬', '7,760', '501']
# ['群\u3000馬', '7,760', '501', '']
# ['群\u3000馬', '7,760', '501', '', '']
# ['高\u3000知']
# ['高\u3000知', '6,702']
# ['高\u3000知', '6,702', '389']
# ['高\u3000知', '6,702', '389', '']
# ['高\u3000知', '6,702', '389', '', '']
# ['福\u3000岡']
# ['福\u3000岡', '5,849']
# ['福\u3000岡', '5,849', '427']
# ['福\u3000岡', '5,849', '427', '']
# ['福\u3000岡', '5,849', '427', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '4,909']
# ['熊\u3000本', '4,909', '354']
# ['熊\u3000本', '4,909', '354', '']
# ['熊\u3000本', '4,909', '354', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '4,276']
# ['茨\u3000城', '4,276', '232']
# ['茨\u3000城', '4,276', '232', '']
# ['茨\u3000城', '4,276', '232', '', '']
# ['トマト']
# ['トマト', '62,375']
# ['トマト', '62,375', '327']
# ['トマト', '62,375', '327', '142.2']
# ['トマト', '62,375', '327', '142.2', '111.6']
# ['栃\u3000木']
# ['栃\u3000木', '13,743']
# ['栃\u3000木', '13,743', '331']
# ['栃\u3000木', '13,743', '331', '']
# ['栃\u3000木', '13,743', '331', '', '']
# ['神奈川']
# ['神奈川', '7,246']
# ['神奈川', '7,246', '259']
# ['神奈川', '7,246', '259', '']
# ['神奈川', '7,246', '259', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '6,956']
# ['熊\u3000本', '6,956', '310']
# ['熊\u3000本', '6,956', '310', '']
# ['熊\u3000本', '6,956', '310', '', '']
# ['北海道']
# ['北海道', '5,897']
# ['北海道', '5,897', '408']
# ['北海道', '5,897', '408', '']
# ['北海道', '5,897', '408', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '5,583']
# ['千\u3000葉', '5,583', '285']
# ['千\u3000葉', '5,583', '285', '']
# ['千\u3000葉', '5,583', '285', '', '']
# ['ミニトマト']
# ['ミニトマト', '15,356']
# ['ミニトマト', '15,356', '527']
# ['ミニトマト', '15,356', '527', '109.0']
# ['ミニトマト', '15,356', '527', '109.0', '106.5']
# ['愛\u3000知']
# ['愛\u3000知', '5,076']
# ['愛\u3000知', '5,076', '567']
# ['愛\u3000知', '5,076', '567', '']
# ['愛\u3000知', '5,076', '567', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '2,529']
# ['熊\u3000本', '2,529', '290']
# ['熊\u3000本', '2,529', '290', '']
# ['熊\u3000本', '2,529', '290', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '1,770']
# ['茨\u3000城', '1,770', '510']
# ['茨\u3000城', '1,770', '510', '']
# ['茨\u3000城', '1,770', '510', '', '']
# ['静\u3000岡']
# ['静\u3000岡', '1,399']
# ['静\u3000岡', '1,399', '518']
# ['静\u3000岡', '1,399', '518', '']
# ['静\u3000岡', '1,399', '518', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '1,322']
# ['千\u3000葉', '1,322', '539']
# ['千\u3000葉', '1,322', '539', '']
# ['千\u3000葉', '1,322', '539', '', '']
# ['ピーマン']
# ['ピーマン', '20,908']
# ['ピーマン', '20,908', '418']
# ['ピーマン', '20,908', '418', '112.6']
# ['ピーマン', '20,908', '418', '112.6', '102.7']
# ['茨\u3000城']
# ['茨\u3000城', '11,382']
# ['茨\u3000城', '11,382', '419']
# ['茨\u3000城', '11,382', '419', '']
# ['茨\u3000城', '11,382', '419', '', '']
# ['高\u3000知']
# ['高\u3000知', '1,785']
# ['高\u3000知', '1,785', '393']
# ['高\u3000知', '1,785', '393', '']
# ['高\u3000知', '1,785', '393', '', '']
# ['岩\u3000手']
# ['岩\u3000手', '1,658']
# ['岩\u3000手', '1,658', '537']
# ['岩\u3000手', '1,658', '537', '']
# ['岩\u3000手', '1,658', '537', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '1,555']
# ['熊\u3000本', '1,555', '447']
# ['熊\u3000本', '1,555', '447', '']
# ['熊\u3000本', '1,555', '447', '', '']
# ['宮\u3000崎']
# ['宮\u3000崎', '617']
# ['宮\u3000崎', '617', '528']
# ['宮\u3000崎', '617', '528', '']
# ['宮\u3000崎', '617', '528', '', '']
# ['ししとう']
# ['ししとう', '904']
# ['ししとう', '904', '1,308']
# ['ししとう', '904', '1,308', '86.9']
# ['ししとう', '904', '1,308', '86.9', '101.2']
# ['高\u3000知']
# ['高\u3000知', '446']
# ['高\u3000知', '446', '1,219']
# ['高\u3000知', '446', '1,219', '']
# ['高\u3000知', '446', '1,219', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '367']
# ['千\u3000葉', '367', '1,409']
# ['千\u3000葉', '367', '1,409', '']
# ['千\u3000葉', '367', '1,409', '', '']
# ['スイトコーン']
# ['スイトコーン', '43,655']
# ['スイトコーン', '43,655', '269']
# ['スイトコーン', '43,655', '269', '154.8']
# ['スイトコーン', '43,655', '269', '154.8', '102.7']
# ['茨\u3000城']
# ['茨\u3000城', '14,790']
# ['茨\u3000城', '14,790', '273']
# ['茨\u3000城', '14,790', '273', '']
# ['茨\u3000城', '14,790', '273', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '10,775']
# ['千\u3000葉', '10,775', '277']
# ['千\u3000葉', '10,775', '277', '']
# ['千\u3000葉', '10,775', '277', '', '']
# ['埼\u3000玉']
# ['埼\u3000玉', '5,400']
# ['埼\u3000玉', '5,400', '252']
# ['埼\u3000玉', '5,400', '252', '']
# ['埼\u3000玉', '5,400', '252', '', '']
# ['栃\u3000木']
# ['栃\u3000木', '4,525']
# ['栃\u3000木', '4,525', '273']
# ['栃\u3000木', '4,525', '273', '']
# ['栃\u3000木', '4,525', '273', '', '']
# ['さやいんげん']
# ['さやいんげん', '2,408']
# ['さやいんげん', '2,408', '793']
# ['さやいんげん', '2,408', '793', '98.3']
# ['さやいんげん', '2,408', '793', '98.3', '99.2']
# ['茨\u3000城']
# ['茨\u3000城', '1,225']
# ['茨\u3000城', '1,225', '785']
# ['茨\u3000城', '1,225', '785', '']
# ['茨\u3000城', '1,225', '785', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '302']
# ['千\u3000葉', '302', '740']
# ['千\u3000葉', '302', '740', '']
# ['千\u3000葉', '302', '740', '', '']
# ['長\u3000崎']
# ['長\u3000崎', '260']
# ['長\u3000崎', '260', '744']
# ['長\u3000崎', '260', '744', '']
# ['長\u3000崎', '260', '744', '', '']
# ['福\u3000島']
# ['福\u3000島', '213']
# ['福\u3000島', '213', '1,106']
# ['福\u3000島', '213', '1,106', '']
# ['福\u3000島', '213', '1,106', '', '']
# ['さやえんどう']
# ['さやえんどう', '1,860']
# ['さやえんどう', '1,860', '1,191']
# ['さやえんどう', '1,860', '1,191', '105.2']
# ['さやえんどう', '1,860', '1,191', '105.2', '105.4']
# ['秋\u3000田']
# ['秋\u3000田', '782']
# ['秋\u3000田', '782', '1,172']
# ['秋\u3000田', '782', '1,172', '']
# ['秋\u3000田', '782', '1,172', '', '']
# ['岩\u3000手']
# ['岩\u3000手', '471']
# ['岩\u3000手', '471', '1,484']
# ['岩\u3000手', '471', '1,484', '']
# ['岩\u3000手', '471', '1,484', '', '']
# ['青\u3000森']
# ['青\u3000森', '292']
# ['青\u3000森', '292', '1,377']
# ['青\u3000森', '292', '1,377', '']
# ['青\u3000森', '292', '1,377', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '226']
# ['\u3000\u3000うち輸入', '226', '402']
# ['\u3000\u3000うち輸入', '226', '402', '127.0']
# ['\u3000\u3000うち輸入', '226', '402', '127.0', '106.1']
# ['実えんどう']
# ['実えんどう', '15']
# ['実えんどう', '15', '1,080']
# ['実えんどう', '15', '1,080', '36.6']
# ['実えんどう', '15', '1,080', '36.6', '103.8']
# ['長\u3000野']
# ['長\u3000野', '15']
# ['長\u3000野', '15', '1,080']
# ['長\u3000野', '15', '1,080', '']
# ['長\u3000野', '15', '1,080', '', '']
# ['そらまめ']
# ['そらまめ', '5,188']
# ['そらまめ', '5,188', '393']
# ['そらまめ', '5,188', '393', '146.6']
# ['そらまめ', '5,188', '393', '146.6', '84.7']
# ['秋\u3000田']
# ['秋\u3000田', '5,188']
# ['秋\u3000田', '5,188', '393']
# ['秋\u3000田', '5,188', '393', '']
# ['秋\u3000田', '5,188', '393', '', '']
# ['えだまめ']
# ['えだまめ', '6,816']
# ['えだまめ', '6,816', '995']
# ['えだまめ', '6,816', '995', '112.2']
# ['えだまめ', '6,816', '995', '112.2', '97.8']
# ['埼\u3000玉']
# ['埼\u3000玉', '3,101']
# ['埼\u3000玉', '3,101', '942']
# ['埼\u3000玉', '3,101', '942', '']
# ['埼\u3000玉', '3,101', '942', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '2,741']
# ['群\u3000馬', '2,741', '1,050']
# ['群\u3000馬', '2,741', '1,050', '']
# ['群\u3000馬', '2,741', '1,050', '', '']
# ['かんしょ']
# ['かんしょ', '20,266']
# ['かんしょ', '20,266', '198']
# ['かんしょ', '20,266', '198', '108.4']
# ['かんしょ', '20,266', '198', '108.4', '105.3']
# ['千\u3000葉']
# ['千\u3000葉', '16,340']
# ['千\u3000葉', '16,340', '186']
# ['千\u3000葉', '16,340', '186', '']
# ['千\u3000葉', '16,340', '186', '', '']
# ['ばれいしょ']
# ['ばれいしょ', '53,111']
# ['ばれいしょ', '53,111', '71']
# ['ばれいしょ', '53,111', '71', '67.0']
# ['ばれいしょ', '53,111', '71', '67.0', '154.3']
# ['長\u3000崎']
# ['長\u3000崎', '24,950']
# ['長\u3000崎', '24,950', '55']
# ['長\u3000崎', '24,950', '55', '']
# ['長\u3000崎', '24,950', '55', '', '']
# ['茨\u3000城']
# ['茨\u3000城', '9,452']
# ['茨\u3000城', '9,452', '68']
# ['茨\u3000城', '9,452', '68', '']
# ['茨\u3000城', '9,452', '68', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '7,750']
# ['熊\u3000本', '7,750', '79']
# ['熊\u3000本', '7,750', '79', '']
# ['熊\u3000本', '7,750', '79', '', '']
# ['静\u3000岡']
# ['静\u3000岡', '7,032']
# ['静\u3000岡', '7,032', '96']
# ['静\u3000岡', '7,032', '96', '']
# ['静\u3000岡', '7,032', '96', '', '']
# ['さといも']
# ['さといも', '1,285']
# ['さといも', '1,285', '404']
# ['さといも', '1,285', '404', '62.3']
# ['さといも', '1,285', '404', '62.3', '95.5']
# ['千\u3000葉']
# ['千\u3000葉', '985']
# ['千\u3000葉', '985', '384']
# ['千\u3000葉', '985', '384', '']
# ['千\u3000葉', '985', '384', '', '']
# ['鹿児島']
# ['鹿児島', '125']
# ['鹿児島', '125', '674']
# ['鹿児島', '125', '674', '']
# ['鹿児島', '125', '674', '', '']
# ['やまのいも']
# ['やまのいも', '13,612']
# ['やまのいも', '13,612', '351']
# ['やまのいも', '13,612', '351', '117.0']
# ['やまのいも', '13,612', '351', '117.0', '102.9']
# ['北海道']
# ['北海道', '10,020']
# ['北海道', '10,020', '324']
# ['北海道', '10,020', '324', '']
# ['北海道', '10,020', '324', '', '']
# ['青\u3000森']
# ['青\u3000森', '2,120']
# ['青\u3000森', '2,120', '311']
# ['青\u3000森', '2,120', '311', '']
# ['青\u3000森', '2,120', '311', '', '']
# ['たまねぎ']
# ['たまねぎ', '135,137']
# ['たまねぎ', '135,137', '72']
# ['たまねぎ', '135,137', '72', '67.1']
# ['たまねぎ', '135,137', '72', '67.1', '112.5']
# ['佐\u3000賀']
# ['佐\u3000賀', '98,220']
# ['佐\u3000賀', '98,220', '68']
# ['佐\u3000賀', '98,220', '68', '']
# ['佐\u3000賀', '98,220', '68', '', '']
# ['香\u3000川']
# ['香\u3000川', '10,000']
# ['香\u3000川', '10,000', '80']
# ['香\u3000川', '10,000', '80', '']
# ['香\u3000川', '10,000', '80', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '3,630']
# ['\u3000\u3000うち輸入', '3,630', '92']
# ['\u3000\u3000うち輸入', '3,630', '92', '55.9']
# ['\u3000\u3000うち輸入', '3,630', '92', '55.9', '148.4']
# ['にんにく']
# ['にんにく', '1,513']
# ['にんにく', '1,513', '731']
# ['にんにく', '1,513', '731', '74.6']
# ['にんにく', '1,513', '731', '74.6', '81.4']
# ['青\u3000森']
# ['青\u3000森', '508']
# ['青\u3000森', '508', '1,522']
# ['青\u3000森', '508', '1,522', '']
# ['青\u3000森', '508', '1,522', '', '']
# ['千\u3000葉']
# ['千\u3000葉', '4']
# ['千\u3000葉', '4', '988']
# ['千\u3000葉', '4', '988', '']
# ['千\u3000葉', '4', '988', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '1,001']
# ['\u3000\u3000うち輸入', '1,001', '329']
# ['\u3000\u3000うち輸入', '1,001', '329', '78.1']
# ['\u3000\u3000うち輸入', '1,001', '329', '78.1', '101.5']
# ['しょうが']
# ['しょうが', '8,082']
# ['しょうが', '8,082', '712']
# ['しょうが', '8,082', '712', '113.9']
# ['しょうが', '8,082', '712', '113.9', '95.3']
# ['高\u3000知']
# ['高\u3000知', '5,905']
# ['高\u3000知', '5,905', '728']
# ['高\u3000知', '5,905', '728', '']
# ['高\u3000知', '5,905', '728', '', '']
# ['熊\u3000本']
# ['熊\u3000本', '493']
# ['熊\u3000本', '493', '878']
# ['熊\u3000本', '493', '878', '']
# ['熊\u3000本', '493', '878', '', '']
# ['静\u3000岡']
# ['静\u3000岡', '344']
# ['静\u3000岡', '344', '952']
# ['静\u3000岡', '344', '952', '']
# ['静\u3000岡', '344', '952', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '985']
# ['\u3000\u3000うち輸入', '985', '322']
# ['\u3000\u3000うち輸入', '985', '322', '110.3']
# ['\u3000\u3000うち輸入', '985', '322', '110.3', '100.6']
# ['生しいたけ']
# ['生しいたけ', '7,067']
# ['生しいたけ', '7,067', '905']
# ['生しいたけ', '7,067', '905', '125.5']
# ['生しいたけ', '7,067', '905', '125.5', '101.2']
# ['秋\u3000田']
# ['秋\u3000田', '3,190']
# ['秋\u3000田', '3,190', '1,048']
# ['秋\u3000田', '3,190', '1,048', '']
# ['秋\u3000田', '3,190', '1,048', '', '']
# ['岩\u3000手']
# ['岩\u3000手', '2,537']
# ['岩\u3000手', '2,537', '743']
# ['岩\u3000手', '2,537', '743', '']
# ['岩\u3000手', '2,537', '743', '', '']
# ['\u3000\u3000うち輸入']
# ['\u3000\u3000うち輸入', '286']
# ['\u3000\u3000うち輸入', '286', '552']
# ['\u3000\u3000うち輸入', '286', '552', '150.5']
# ['\u3000\u3000うち輸入', '286', '552', '150.5', '97.2']
# ['なめこ']
# ['なめこ', '3,342']
# ['なめこ', '3,342', '394']
# ['なめこ', '3,342', '394', '99.9']
# ['なめこ', '3,342', '394', '99.9', '106.8']
# ['長\u3000野']
# ['長\u3000野', '1,099']
# ['長\u3000野', '1,099', '316']
# ['長\u3000野', '1,099', '316', '']
# ['長\u3000野', '1,099', '316', '', '']
# ['山\u3000形']
# ['山\u3000形', '925']
# ['山\u3000形', '925', '433']
# ['山\u3000形', '925', '433', '']
# ['山\u3000形', '925', '433', '', '']
# ['群\u3000馬']
# ['群\u3000馬', '572']
# ['群\u3000馬', '572', '409']
# ['群\u3000馬', '572', '409', '']
# ['群\u3000馬', '572', '409', '', '']
# ['新\u3000潟']
# ['新\u3000潟', '520']
# ['新\u3000潟', '520', '501']
# ['新\u3000潟', '520', '501', '']
# ['新\u3000潟', '520', '501', '', '']
# ['えのきだけ']
# ['えのきだけ', '6,720']
# ['えのきだけ', '6,720', '222']
# ['えのきだけ', '6,720', '222', '88.6']
# ['えのきだけ', '6,720', '222', '88.6', '113.8']
# ['長\u3000野']
# ['長\u3000野', '5,502']
# ['長\u3000野', '5,502', '226']
# ['長\u3000野', '5,502', '226', '']
# ['長\u3000野', '5,502', '226', '', '']
# ['しめじ']
# ['しめじ', '6,407']
# ['しめじ', '6,407', '332']
# ['しめじ', '6,407', '332', '73.0']
# ['しめじ', '6,407', '332', '73.0', '99.7']
# ['長\u3000野']
# ['長\u3000野', '4,728']
# ['長\u3000野', '4,728', '345']
# ['長\u3000野', '4,728', '345', '']
# ['長\u3000野', '4,728', '345', '', '']
# ['新\u3000潟']
# ['新\u3000潟', '914']
# ['新\u3000潟', '914', '318']
# ['新\u3000潟', '914', '318', '']
# ['新\u3000潟', '914', '318', '', '']
# ['その他の野菜']
# ['その他の野菜', '53,549']
# ['その他の野菜', '53,549', '561']
# ['その他の野菜', '53,549', '561', '118.5']
# ['その他の野菜', '53,549', '561', '118.5', '94.8']
# ['輸入野菜計']
# ['輸入野菜計', '35,471']
# ['輸入野菜計', '35,471', '190']
# ['輸入野菜計', '35,471', '190', '82.3']
# ['輸入野菜計', '35,471', '190', '82.3', '113.1']
# ['他の輸入野菜']
# ['他の輸入野菜', '11,918']
# ['他の輸入野菜', '11,918', '274']
# ['他の輸入野菜', '11,918', '274', '90.3']
# ['他の輸入野菜', '11,918', '274', '90.3', '111.8']
# ['\n                    ［利用上の注意］\n                    １．\u3000上記の数値については、日々の確定値として収集してい\n                    \u3000\u3000るが、その後修正することも予想されることから、数値の\n                    \u3000\u3000利用にあたっては十分に留意されたい。\n                    ２．\u3000産地については、品目毎に卸売数量の多い都道府県から\n                    \u3000\u3000順に配列し、８０％を上回るまでの産地のうち、卸売数量\n\n                    \u3000\u3000の多い都道府県から最大５産地を掲載する。\n                    ３．\u3000以上に掲げる品目のうち、以下の「品目名」については\n                    \u3000\u3000略称名である。\n                    \u3000\u3000\u3000ししとう\u3000\u3000・・・ししとうがらし\n                    \u3000\u3000\u3000スイトコーン・・・スイートコーン\n                    \u3000\u3000\u3000ネーブル\u3000\u3000・・・ネーブルオレンジ\n\n                    \u3000\u3000\u3000ジョナゴルド・・・ジョナゴールド\n                    \u3000\u3000\u3000アンデス\u3000\u3000・・・アンデスメロン\n                    \u3000\u3000\u3000キウイフルツ・・・キウイフルーツ\n                    \u3000\u3000\u3000パイナップル・・・パインアップル\n                    \u3000\u3000\u3000グレプフルツ・・・グレープフルーツ\n                    \u3000\u3000\u3000輸入キウイ\u3000・・・輸入キウイフルーツ']

# %%
col_names = [ 'c{0:02d}'.format(i) for i in range(5) ]
#columnsサイズが特定できない場合は先に名前をつけてあげないとエラーが出る
df = pd.read_csv('oroshi.csv', encoding='shift-jis',names=col_names)

# %%
df[:8]
# Out:
#       c00        c01       c02    c03    c04
# 0  品目名／産地     数量(kg)  価格(円/kg)   対前日比    NaN
# 1   数量(％)      価格(％)       NaN    NaN    NaN
# 2    野菜総量  1,149,087       242  105.1  109.5
# 3     長　野    157,571       182    NaN    NaN
# 4     茨　城    142,061       237    NaN    NaN
# 5     群　馬    126,119       222    NaN    NaN
# 6     千　葉    115,856       204    NaN    NaN
# 7     佐　賀    100,548        92    NaN    NaN

# %% [markdown]
# 表全体を読み込むことができた。しかしcolumnの位置がずれている

# %% [markdown]
# ## HTMLからデータを取得し、エクセルファイルに変換（beautifulsoup+openyxl)<br>

# %%
#htmlパース用のオブジェクト作成(上記の通り今回は保存済み　HTMLを使用)
# soup = BeautifulSoup(r.text, 'lxml') #要素を抽出

soup = BeautifulSoup(open('oroshi.html', encoding='utf-8'), 'html.parser')

# %%
import openpyxl as px

# %%
if __name__ == '__main__':

    wb = px.Workbook()
    ws = wb.active

    # 標準だと `Sheet` だが変更する場合は `title` で変更する
    ws.title = "WorkSheetTitle"
    
    # セルに値を入れる
    ws["A1"] = "品目名／産地"
    ws["B1"] = "数量(kg)"
    ws["C1"] = "価格(円/kg)"
    
# 行列表記でセルに値を入れる
#Tableを指定
    tables = soup.find_all("table")
    for table in tables:
        rows = [row for row in table.find_all('tr')]
        
        count = 1
        for row in rows:
            csvRow = []
            for cell in row.find_all(['td','th']):
                csvRow.append(cell.get_text())

            ws.cell(row= count, column=1).value = csvRow[0]
            count += 1
            if len(csvRow) > 1:
                ws.cell(row= count, column=2).value = csvRow[1]
            if len(csvRow) > 2:ws.cell(row= count, column=3).value = csvRow[2]
           

    # 保存
    wb.save('oroshi.xlsx')
    wb.close()

# %%
#excelファイルを読み込む
df = pd.read_excel('oroshi.xlsx')

# %%
df[:10]
# Out:
#   品目名／産地     数量(kg)  価格(円/kg)
# 0  数量(％)     数量(kg)  価格(円/kg)
# 1   野菜総量      価格(％)       NaN
# 2    長　野  1,149,087       242
# 3    茨　城    157,571       182
# 4    群　馬    142,061       237
# 5    千　葉    126,119       222
# 6    佐　賀    115,856       204
# 7    青　森    100,548        92
# 8    福　島     56,855       163
# 9   だいこん     46,890       276

# %% [markdown]
# ## urlopen()とBeautifulSoup

# %%
import urllib.request as req

url = "http://api.aoikujira.com/zip/xml/1500042"

#urlopen()でデータを取得
res = req.urlopen(url)

#beautifulSoupで解析
soup = BeautifulSoup(res, "html.parser")

#任意のデータを抽出
ken = soup.find("ken").string
shi = soup.find("shi").string
cho = soup.find("cho").string

print(ken, shi, cho)
# Out:
# 東京都 渋谷区 宇田川町

# %% [markdown]
# 【HTML】
# ```
# <address result="1">
# <header>
# <result>1</result>
# <api>api.aoikujira.com/zip</api>
# <version>1.1</version>
# </header>
# <value>
# <zip>1500042</zip>
# <ken>東京都</ken>
# <shi>渋谷区</shi>
# <cho>宇田川町</cho>
# <disp>東京都渋谷区宇田川町</disp>
# <kenkana>トウキョウト</kenkana>
# <shikana>シブヤク</shikana>
# <chokana>ウダガワチョウ</chokana>
# </value>
# </address>
# ```

# %% [markdown]
# ## CSSセレクタを使う

# %%
from bs4 import BeautifulSoup 

# 解析対象となるHTML --- (※1)
html = """
<html><body>
<div id="meigen">
  <h1>トルストイの名言</h1>
  <ul class="items">
    <li>汝の心に教えよ、心に学ぶな</li>
    <li>謙虚な人は誰からも好かれる。</li>
    <li>強い人々は、いつも気取らない。</li>
  </ul>
</div>
</body></html>
"""

# HTMLを解析する --- (※2)
soup = BeautifulSoup(html, 'html.parser')

# 必要な部分をCSSクエリで取り出す
# | タイトル部分を取得 --- (※3)
h1 = soup.select_one("div#meigen > h1").string
print("h1 =", h1)

# | リスト部分を取得 --- (※4)
li_list = soup.select("div#meigen > ul.items > li")
for li in li_list:
	print("li =", li.string)
# Out:
# h1 = トルストイの名言
# li = 汝の心に教えよ、心に学ぶな
# li = 謙虚な人は誰からも好かれる。
# li = 強い人々は、いつも気取らない。
